# %%
i

# %%
def realizar_operacoes(num1, num2):
    print("Operações com os números digitados:")
    print("Adição:", num1 + num2)
    print("Subtração:", num1 - num2)
    print("Multiplicação:", num1 * num2)
    print("Divisão:", num1 / num2)
    print("Divisão inteira:", num1 // num2)

    if num1 > num2:
        print("O primeiro número é maior que o segundo.")
    elif num1 < num2:
        print("O segundo número é maior que o primeiro.")
    else:
        print("Os números são iguais.")

while True:
    try:
        num = input("Digite o primeiro número para começar (ou 'sair' para encerrar): ")
        if num.lower() == 'sair':
            print("Encerrando o programa.")
            break
        num2 = input("Digite o segundo número: ")

        num_convert = int(num)
        num2_convert = int(num2)

        realizar_operacoes(num_convert, num2_convert)

    except ValueError:
        print("Entrada inválida. Certifique-se de inserir números.")
# Out:
# Digite o primeiro número para começar (ou 'sair' para encerrar): 8
# Digite o segundo número: 8
# Operações com os números digitados:
# Adição: 16
# Subtração: 0
# Multiplicação: 64
# Divisão: 1.0
# Divisão inteira: 1
# Os números são iguais.
# Digite o primeiro número para começar (ou 'sair' para encerrar): 9
# Digite o segundo número: 10
# Operações com os números digitados:
# Adição: 19
# Subtração: -1
# Multiplicação: 90
# Divisão: 0.9
# Divisão inteira: 0
# O segundo número é maior que o primeiro.
# Digite o primeiro número para começar (ou 'sair' para encerrar): k
# Digite o segundo número: l
# Entrada inválida. Certifique-se de inserir números.
# Digite o primeiro número para começar (ou 'sair' para encerrar): l
# Digite o segundo número: l
# Entrada inválida. Certifique-se de inserir números.
# Digite o primeiro número para começar (ou 'sair' para encerrar): sair
# Encerrando o programa.
